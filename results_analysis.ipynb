# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# %%
import sys
sys.path.append("/project/")

from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter, PercentFormatter
import seaborn as sns
import matplotlib.lines as mlines


from utils import get_df

# %%
ALGO_LIST = [
    # "mcpg_me",
    # "dcg_me",
    "pga_me",
    # "me",
    # "memes",
]

# %%
results_dir = Path("fig2/output/")
EPISODE_LENGTH = 250
df = get_df(results_dir, EPISODE_LENGTH)
#df['algo'] = df.apply(filter, axis=1)
df = df[df["algo"].isin(ALGO_LIST)]
df = df[df["num_evaluations"] <= 1_005_000]
# Out:
# ant_uni_250
# walker2d_uni_250
# ant_omni_250
# hopper_uni_250
# anttrap_omni_250

# %%
idx = df.groupby(["env", "algo", "run"])["iteration"].idxmax()
df_last_iteration = df.loc[idx]
df = df_last_iteration[['env', 'algo', 'time', 'qd_score', 'batch_size']]

# %%
new_df = df[df['batch_size'] == 1024]

# %%
new_df
# Out:
#                       env    algo        time       qd_score  batch_size
# 1364530      ant_omni_250  pga_me  831.462769  162727.843750        1024
# 1367530      ant_omni_250  pga_me  842.631165  213328.546875        1024
# 1370530      ant_omni_250  pga_me  828.015381  194135.296875        1024
# 1373530      ant_omni_250  pga_me  841.567688  339750.500000        1024
# 1376530      ant_omni_250  pga_me  829.037292  245094.484375        1024
# 323480        ant_uni_250  pga_me  815.739136  527710.437500        1024
# 326480        ant_uni_250  pga_me  814.258911  462873.468750        1024
# 329480        ant_uni_250  pga_me  807.557861  516441.625000        1024
# 332480        ant_uni_250  pga_me  822.095154  447725.843750        1024
# 335480        ant_uni_250  pga_me  803.623352  542534.375000        1024
# 1849180  anttrap_omni_250  pga_me  952.548584  265068.937500        1024
# 1850680  anttrap_omni_250  pga_me  942.605408  390427.000000        1024
# 1852180  anttrap_omni_250  pga_me  939.743469  181924.406250        1024
# 1853680  anttrap_omni_250  pga_me  939.340515  324811.312500        1024
# 1855180  anttrap_omni_250  pga_me  941.829834  225388.968750        1024
# 1615130    hopper_uni_250  pga_me  701.383789  475958.437500        1024
# 1616630    hopper_uni_250  pga_me  710.694214  450606.500000        1024
# 1618130    hopper_uni_250  pga_me  697.126038  491777.593750        1024
# 1619630    hopper_uni_250  pga_me  699.257385  433111.187500        1024
# 1621130    hopper_uni_250  pga_me  705.774292  476062.875000        1024
# 779880   walker2d_uni_250  pga_me  723.857605  556164.062500        1024
# 782880   walker2d_uni_250  pga_me  720.098755  540206.750000        1024
# 785880   walker2d_uni_250  pga_me  730.641418  550490.500000        1024
# 788880   walker2d_uni_250  pga_me  730.400024  511294.031250        1024
# 791880   walker2d_uni_250  pga_me  729.914429  543509.562500        1024
