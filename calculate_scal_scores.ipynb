# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# %%
import sys
sys.path.append("/project/")

from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter, PercentFormatter
import seaborn as sns
import matplotlib.lines as mlines


from utils import get_df

# %%
results_dir = Path("fig2/output/")
EPISODE_LENGTH = 250
df = get_df(results_dir, EPISODE_LENGTH)
df = df[df["num_evaluations"] <= 1_005_000]
# Out:
# ant_uni_250
# walker2d_uni_250
# ant_omni_250

# %%
df
# Out:
#          coverage  ga_offspring_added  iteration  max_fitness       qd_score  \
# 0        0.049805                  11          1   254.512100    5732.699219
# 1        0.100586                  39          2   278.935730   11091.748047
# 2        0.149414                  49          3   278.935730   17261.589844
# 3        0.182617                  42          4   278.935730   22521.285156
# 4        0.212891                  40          5   278.935730   27726.349609
# ...           ...                 ...        ...          ...            ...
# 1382490  0.395508                   7        241  1006.628174  369324.531250
# 1382491  0.396484                   9        242  1006.628174  370207.250000
# 1382492  0.396484                   7        243  1006.628174  370230.812500
# 1382493  0.396484                   4        244  1006.628174  370246.062500
# 1382494  0.398438                   7        245  1006.628174  372207.562500
#
#          qpg_offspring_added        time           env     algo  batch_size  \
# 0                       40.0   13.347132   ant_uni_250  mcpg_me         256
# 1                       37.0   13.347132   ant_uni_250  mcpg_me         256
# 2                       35.0   13.347132   ant_uni_250  mcpg_me         256
# 3                       36.0   13.347132   ant_uni_250  mcpg_me         256
# 4                       25.0   13.347132   ant_uni_250  mcpg_me         256
# ...                      ...         ...           ...      ...         ...
# 1382490                  0.0  600.714294  ant_omni_250   pga_me        4096
# 1382491                  0.0  600.714294  ant_omni_250   pga_me        4096
# 1382492                  0.0  600.714294  ant_omni_250   pga_me        4096
# 1382493                  0.0  600.714294  ant_omni_250   pga_me        4096
# 1382494                  0.0  600.714294  ant_omni_250   pga_me        4096
#
#          proportion_mutation_ga  no_epochs   gpu                       run  \
# 0                           0.5       32.0  L40S  2024-12-15_194702_882401
# 1                           0.5       32.0  L40S  2024-12-15_194702_882401
# 2                           0.5       32.0  L40S  2024-12-15_194702_882401
# 3                           0.5       32.0  L40S  2024-12-15_194702_882401
# 4                           0.5       32.0  L40S  2024-12-15_194702_882401
# ...                         ...        ...   ...                       ...
# 1382490                     NaN        NaN  L40S  2024-12-16_121228_982863
# 1382491                     NaN        NaN  L40S  2024-12-16_121228_982863
# 1382492                     NaN        NaN  L40S  2024-12-16_121228_982863
# 1382493                     NaN        NaN  L40S  2024-12-16_121228_982863
# 1382494                     NaN        NaN  L40S  2024-12-16_121228_982863
#
#          num_evaluations  ai_offspring_added  ga_batch_size
# 0                    256                 NaN            NaN
# 1                    512                 NaN            NaN
# 2                    768                 NaN            NaN
# 3                   1024                 NaN            NaN
# 4                   1280                 NaN            NaN
# ...                  ...                 ...            ...
# 1382490           987136                 0.0            NaN
# 1382491           991232                 0.0            NaN
# 1382492           995328                 0.0            NaN
# 1382493           999424                 0.0            NaN
# 1382494          1003520                 0.0            NaN
#
# [452255 rows x 17 columns]

# %%
idx = df.groupby(["env", "algo", "run"])["iteration"].idxmax()
df_last_iteration = df.loc[idx]
df = df_last_iteration[['env', 'algo', 'time', 'qd_score', 'batch_size']]

# %%
df[['qd_score', 'time']] = df.groupby('env')[['qd_score', 'time']].transform(
    lambda x: (x - x.min()) / (x.max() - x.min())
)
# Out:
# /tmp/ipykernel_3383424/2664997091.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['qd_score', 'time']] = df.groupby('env')[['qd_score', 'time']].transform(

# %%
df
# Out:
#                      env    algo      time  qd_score  batch_size
# 921924      ant_omni_250  dcg_me  0.854894  1.000000         256
# 933924      ant_omni_250  dcg_me  0.853530  0.962190         256
# 945924      ant_omni_250  dcg_me  0.853705  0.979123         256
# 957924      ant_omni_250  dcg_me  0.854717  0.987238         256
# 969924      ant_omni_250  dcg_me  0.862550  0.985592         256
# ...                  ...     ...       ...       ...         ...
# 798244  walker2d_uni_250  pga_me  0.241856  0.365650        4096
# 798994  walker2d_uni_250  pga_me  0.242159  0.342361        4096
# 799744  walker2d_uni_250  pga_me  0.245499  0.329949        4096
# 800494  walker2d_uni_250  pga_me  0.243895  0.316296        4096
# 801244  walker2d_uni_250  pga_me  0.243638  0.291005        4096
#
# [299 rows x 5 columns]

# %%
df = df.groupby(['env', 'algo', 'batch_size'])[['qd_score', 'time']].median().reset_index()

# %%
df
# Out:
#                  env     algo  batch_size  qd_score      time
# 0       ant_omni_250   dcg_me         256  0.985592  0.854717
# 1       ant_omni_250   dcg_me         512  0.975532  0.438085
# 2       ant_omni_250   dcg_me        1024  0.970870  0.240826
# 3       ant_omni_250   dcg_me        2048  0.876803  0.140914
# 4       ant_omni_250   dcg_me        4096  0.534603  0.127922
# 5       ant_omni_250  mcpg_me         256  0.749842  0.164136
# 6       ant_omni_250  mcpg_me         512  0.712879  0.080619
# 7       ant_omni_250  mcpg_me        1024  0.682098  0.043118
# 8       ant_omni_250  mcpg_me        2048  0.804054  0.026472
# 9       ant_omni_250  mcpg_me        4096  0.800135  0.020903
# 10      ant_omni_250       me         256  0.090232  0.147221
# 11      ant_omni_250       me         512  0.133572  0.068911
# 12      ant_omni_250       me        1024  0.129726  0.032338
# 13      ant_omni_250       me        2048  0.130666  0.009043
# 14      ant_omni_250       me        4096  0.121864  0.000008
# 15      ant_omni_250   pga_me         256  0.057853  0.989017
# 16      ant_omni_250   pga_me         512  0.077709  0.525192
# 17      ant_omni_250   pga_me        1024  0.071005  0.308473
# 18      ant_omni_250   pga_me        2048  0.075542  0.259217
# 19      ant_omni_250   pga_me        4096  0.109585  0.216273
# 20       ant_uni_250   dcg_me         256  0.756941  0.867994
# 21       ant_uni_250   dcg_me         512  0.810730  0.445689
# 22       ant_uni_250   dcg_me        1024  0.924516  0.239894
# 23       ant_uni_250   dcg_me        2048  0.992646  0.145176
# 24       ant_uni_250   dcg_me        4096  0.944722  0.127541
# 25       ant_uni_250  mcpg_me         256  0.353014  0.166003
# 26       ant_uni_250  mcpg_me         512  0.337240  0.081207
# 27       ant_uni_250  mcpg_me        1024  0.352366  0.043310
# 28       ant_uni_250  mcpg_me        2048  0.346852  0.026056
# 29       ant_uni_250  mcpg_me        4096  0.374182  0.021911
# 30       ant_uni_250       me         256  0.047879  0.164212
# 31       ant_uni_250       me         512  0.058224  0.070304
# 32       ant_uni_250       me        1024  0.027879  0.030036
# 33       ant_uni_250       me        2048  0.070591  0.010765
# 34       ant_uni_250       me        4096  0.069585  0.000134
# 35       ant_uni_250   pga_me         256  0.785970  0.985684
# 36       ant_uni_250   pga_me         512  0.762254  0.523789
# 37       ant_uni_250   pga_me        1024  0.780595  0.306618
# 38       ant_uni_250   pga_me        2048  0.698015  0.258895
# 39       ant_uni_250   pga_me        4096  0.479817  0.219913
# 40  walker2d_uni_250   dcg_me         256  0.579255  0.884270
# 41  walker2d_uni_250   dcg_me         512  0.560521  0.458336
# 42  walker2d_uni_250   dcg_me        1024  0.599697  0.247072
# 43  walker2d_uni_250   dcg_me        2048  0.541431  0.156887
# 44  walker2d_uni_250   dcg_me        4096  0.516643  0.141223
# 45  walker2d_uni_250  mcpg_me         256  0.805654  0.089089
# 46  walker2d_uni_250  mcpg_me         512  0.768526  0.048554
# 47  walker2d_uni_250  mcpg_me        1024  0.911981  0.028853
# 48  walker2d_uni_250  mcpg_me        2048  0.874172  0.023312
# 49  walker2d_uni_250  mcpg_me        4096  0.870625  0.022916
# 50  walker2d_uni_250       me         256  0.162361  0.072388
# 51  walker2d_uni_250       me         512  0.136011  0.033878
# 52  walker2d_uni_250       me        1024  0.170334  0.014334
# 53  walker2d_uni_250       me        2048  0.168917  0.004257
# 54  walker2d_uni_250       me        4096  0.176876  0.000059
# 55  walker2d_uni_250   pga_me         256  0.362008  0.983994
# 56  walker2d_uni_250   pga_me         512  0.374258  0.531328
# 57  walker2d_uni_250   pga_me        1024  0.365371  0.320072
# 58  walker2d_uni_250   pga_me        2048  0.359607  0.277655
# 59  walker2d_uni_250   pga_me        4096  0.329949  0.243638

# %%
df['time'] = 1 - df['time']

# %%
df
# Out:
#                  env     algo  batch_size  qd_score      time
# 0       ant_omni_250   dcg_me         256  1.000000  0.135792
# 1       ant_omni_250   dcg_me         512  0.989157  0.557055
# 2       ant_omni_250   dcg_me        1024  0.984132  0.756506
# 3       ant_omni_250   dcg_me        2048  0.882738  0.857528
# 4       ant_omni_250   dcg_me        4096  0.513884  0.870664
# 5       ant_omni_250  mcpg_me         256  0.745888  0.834048
# 6       ant_omni_250  mcpg_me         512  0.706045  0.918493
# 7       ant_omni_250  mcpg_me        1024  0.672867  0.956411
# 8       ant_omni_250  mcpg_me        2048  0.804323  0.973242
# 9       ant_omni_250  mcpg_me        4096  0.800098  0.978872
# 10      ant_omni_250       me         256  0.034900  0.851151
# 11      ant_omni_250       me         512  0.081616  0.930331
# 12      ant_omni_250       me        1024  0.077471  0.967310
# 13      ant_omni_250       me        2048  0.078484  0.990864
# 14      ant_omni_250       me        4096  0.068996  1.000000
# 15      ant_omni_250   pga_me         256  0.000000  0.000000
# 16      ant_omni_250   pga_me         512  0.021402  0.468979
# 17      ant_omni_250   pga_me        1024  0.014176  0.688106
# 18      ant_omni_250   pga_me        2048  0.019066  0.737911
# 19      ant_omni_250   pga_me        4096  0.055760  0.781332
# 20       ant_uni_250   dcg_me         256  0.755687  0.119416
# 21       ant_uni_250   dcg_me         512  0.811440  0.547912
# 22       ant_uni_250   dcg_me        1024  0.929381  0.756725
# 23       ant_uni_250   dcg_me        2048  1.000000  0.852831
# 24       ant_uni_250   dcg_me        4096  0.950325  0.870725
# 25       ant_uni_250  mcpg_me         256  0.337008  0.831699
# 26       ant_uni_250  mcpg_me         512  0.320658  0.917738
# 27       ant_uni_250  mcpg_me        1024  0.336337  0.956191
# 28       ant_uni_250  mcpg_me        2048  0.330621  0.973698
# 29       ant_uni_250  mcpg_me        4096  0.358950  0.977903
# 30       ant_uni_250       me         256  0.020730  0.833517
# 31       ant_uni_250       me         512  0.031454  0.928802
# 32       ant_uni_250       me        1024  0.000000  0.969659
# 33       ant_uni_250       me        2048  0.044272  0.989213
# 34       ant_uni_250       me        4096  0.043229  1.000000
# 35       ant_uni_250   pga_me         256  0.785776  0.000000
# 36       ant_uni_250   pga_me         512  0.761193  0.468667
# 37       ant_uni_250   pga_me        1024  0.780205  0.689023
# 38       ant_uni_250   pga_me        2048  0.694609  0.737445
# 39       ant_uni_250   pga_me        4096  0.468443  0.776999
# 40  walker2d_uni_250   dcg_me         256  0.571214  0.101352
# 41  walker2d_uni_250   dcg_me         512  0.547070  0.534241
# 42  walker2d_uni_250   dcg_me        1024  0.597557  0.748955
# 43  walker2d_uni_250   dcg_me        2048  0.522469  0.840612
# 44  walker2d_uni_250   dcg_me        4096  0.490524  0.856531
# 45  walker2d_uni_250  mcpg_me         256  0.862976  0.909516
# 46  walker2d_uni_250  mcpg_me         512  0.815129  0.950714
# 47  walker2d_uni_250  mcpg_me        1024  1.000000  0.970737
# 48  walker2d_uni_250  mcpg_me        2048  0.951276  0.976368
# 49  walker2d_uni_250  mcpg_me        4096  0.946704  0.976771
# 50  walker2d_uni_250       me         256  0.033958  0.926491
# 51  walker2d_uni_250       me         512  0.000000  0.965629
# 52  walker2d_uni_250       me        1024  0.044232  0.985492
# 53  walker2d_uni_250       me        2048  0.042407  0.995734
# 54  walker2d_uni_250       me        4096  0.052664  1.000000
# 55  walker2d_uni_250   pga_me         256  0.291244  0.000000
# 56  walker2d_uni_250   pga_me         512  0.307031  0.460056
# 57  walker2d_uni_250   pga_me        1024  0.295579  0.674762
# 58  walker2d_uni_250   pga_me        2048  0.288150  0.717872
# 59  walker2d_uni_250   pga_me        4096  0.249930  0.752444

# %%
df['scalability_score'] = df['qd_score'] * df['time']

# %%
df
# Out:
#                  env     algo  batch_size  qd_score      time  \
# 0       ant_omni_250   dcg_me         256  1.000000  0.135792
# 1       ant_omni_250   dcg_me         512  0.989157  0.557055
# 2       ant_omni_250   dcg_me        1024  0.984132  0.756506
# 3       ant_omni_250   dcg_me        2048  0.882738  0.857528
# 4       ant_omni_250   dcg_me        4096  0.513884  0.870664
# 5       ant_omni_250  mcpg_me         256  0.745888  0.834048
# 6       ant_omni_250  mcpg_me         512  0.706045  0.918493
# 7       ant_omni_250  mcpg_me        1024  0.672867  0.956411
# 8       ant_omni_250  mcpg_me        2048  0.804323  0.973242
# 9       ant_omni_250  mcpg_me        4096  0.800098  0.978872
# 10      ant_omni_250       me         256  0.034900  0.851151
# 11      ant_omni_250       me         512  0.081616  0.930331
# 12      ant_omni_250       me        1024  0.077471  0.967310
# 13      ant_omni_250       me        2048  0.078484  0.990864
# 14      ant_omni_250       me        4096  0.068996  1.000000
# 15      ant_omni_250   pga_me         256  0.000000  0.000000
# 16      ant_omni_250   pga_me         512  0.021402  0.468979
# 17      ant_omni_250   pga_me        1024  0.014176  0.688106
# 18      ant_omni_250   pga_me        2048  0.019066  0.737911
# 19      ant_omni_250   pga_me        4096  0.055760  0.781332
# 20       ant_uni_250   dcg_me         256  0.755687  0.119416
# 21       ant_uni_250   dcg_me         512  0.811440  0.547912
# 22       ant_uni_250   dcg_me        1024  0.929381  0.756725
# 23       ant_uni_250   dcg_me        2048  1.000000  0.852831
# 24       ant_uni_250   dcg_me        4096  0.950325  0.870725
# 25       ant_uni_250  mcpg_me         256  0.337008  0.831699
# 26       ant_uni_250  mcpg_me         512  0.320658  0.917738
# 27       ant_uni_250  mcpg_me        1024  0.336337  0.956191
# 28       ant_uni_250  mcpg_me        2048  0.330621  0.973698
# 29       ant_uni_250  mcpg_me        4096  0.358950  0.977903
# 30       ant_uni_250       me         256  0.020730  0.833517
# 31       ant_uni_250       me         512  0.031454  0.928802
# 32       ant_uni_250       me        1024  0.000000  0.969659
# 33       ant_uni_250       me        2048  0.044272  0.989213
# 34       ant_uni_250       me        4096  0.043229  1.000000
# 35       ant_uni_250   pga_me         256  0.785776  0.000000
# 36       ant_uni_250   pga_me         512  0.761193  0.468667
# 37       ant_uni_250   pga_me        1024  0.780205  0.689023
# 38       ant_uni_250   pga_me        2048  0.694609  0.737445
# 39       ant_uni_250   pga_me        4096  0.468443  0.776999
# 40  walker2d_uni_250   dcg_me         256  0.571214  0.101352
# 41  walker2d_uni_250   dcg_me         512  0.547070  0.534241
# 42  walker2d_uni_250   dcg_me        1024  0.597557  0.748955
# 43  walker2d_uni_250   dcg_me        2048  0.522469  0.840612
# 44  walker2d_uni_250   dcg_me        4096  0.490524  0.856531
# 45  walker2d_uni_250  mcpg_me         256  0.862976  0.909516
# 46  walker2d_uni_250  mcpg_me         512  0.815129  0.950714
# 47  walker2d_uni_250  mcpg_me        1024  1.000000  0.970737
# 48  walker2d_uni_250  mcpg_me        2048  0.951276  0.976368
# 49  walker2d_uni_250  mcpg_me        4096  0.946704  0.976771
# 50  walker2d_uni_250       me         256  0.033958  0.926491
# 51  walker2d_uni_250       me         512  0.000000  0.965629
# 52  walker2d_uni_250       me        1024  0.044232  0.985492
# 53  walker2d_uni_250       me        2048  0.042407  0.995734
# 54  walker2d_uni_250       me        4096  0.052664  1.000000
# 55  walker2d_uni_250   pga_me         256  0.291244  0.000000
# 56  walker2d_uni_250   pga_me         512  0.307031  0.460056
# 57  walker2d_uni_250   pga_me        1024  0.295579  0.674762
# 58  walker2d_uni_250   pga_me        2048  0.288150  0.717872
# 59  walker2d_uni_250   pga_me        4096  0.249930  0.752444
#
#     scalability_score
# 0            0.135792
# 1            0.551015
# 2            0.744501
# 3            0.756972
# 4            0.447420
# 5            0.622106
# 6            0.648497
# 7            0.643537
# 8            0.782800
# 9            0.783194
# 10           0.029705
# 11           0.075930
# 12           0.074938
# 13           0.077767
# 14           0.068996
# 15           0.000000
# 16           0.010037
# 17           0.009755
# 18           0.014069
# 19           0.043567
# 20           0.090241
# 21           0.444598
# 22           0.703286
# 23           0.852831
# 24           0.827472
# 25           0.280289
# 26           0.294280
# 27           0.321602
# 28           0.321925
# 29           0.351018
# 30           0.017279
# 31           0.029214
# 32           0.000000
# 33           0.043795
# 34           0.043229
# 35           0.000000
# 36           0.356746
# 37           0.537579
# 38           0.512236
# 39           0.363979
# 40           0.057894
# 41           0.292267
# 42           0.447543
# 43           0.439194
# 44           0.420150
# 45           0.784891
# 46           0.774954
# 47           0.970737
# 48           0.928795
# 49           0.924713
# 50           0.031462
# 51           0.000000
# 52           0.043590
# 53           0.042226
# 54           0.052664
# 55           0.000000
# 56           0.141252
# 57           0.199445
# 58           0.206855
# 59           0.188058

# %%
df = df.loc[df.groupby(['env', 'algo'])['scalability_score'].idxmax()]

# %%
df
# Out:
#                  env     algo  batch_size  qd_score      time  \
# 3       ant_omni_250   dcg_me        2048  0.876803  0.859086
# 9       ant_omni_250  mcpg_me        4096  0.800135  0.979097
# 13      ant_omni_250       me        2048  0.130666  0.990957
# 19      ant_omni_250   pga_me        4096  0.109585  0.783727
# 23       ant_uni_250   dcg_me        2048  0.992646  0.854824
# 29       ant_uni_250  mcpg_me        4096  0.374182  0.978089
# 33       ant_uni_250       me        2048  0.070591  0.989235
# 37       ant_uni_250   pga_me        1024  0.780595  0.693382
# 43  walker2d_uni_250   dcg_me        2048  0.541431  0.843113
# 47  walker2d_uni_250  mcpg_me        1024  0.911981  0.971147
# 54  walker2d_uni_250       me        4096  0.176876  0.999941
# 58  walker2d_uni_250   pga_me        2048  0.359607  0.722345
#
#     scalability_score
# 3            0.753249
# 9            0.783410
# 13           0.129484
# 19           0.085884
# 23           0.848538
# 29           0.365983
# 33           0.069831
# 37           0.541251
# 43           0.456488
# 47           0.885668
# 54           0.176866
# 58           0.259760
