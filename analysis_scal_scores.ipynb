# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# %%
import sys
sys.path.append("/project/")

from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter, PercentFormatter
import seaborn as sns
import matplotlib.lines as mlines


from utils import get_df

# %%
ALGO_LIST = [
    "mcpg_me",
    "dcg_me",
    "pga_me",
    "me",
    "memes",
    "ppga",
]

# %%
BATCH_LIST = [
    256,
    512,
    1024,
    2048,
    4096,
]

# %%
results_dir = Path("fig2/output/")
EPISODE_LENGTH = 250
df = get_df(results_dir, EPISODE_LENGTH)
#df['algo'] = df.apply(filter, axis=1)
df = df[df["algo"].isin(ALGO_LIST)]
#df = df[df["batch_size"].isin(BATCH_LIST)]
df = df[df["num_evaluations"] <= 1_005_000]
# Out:
# ant_uni_250
# walker2d_uni_250
# ant_omni_250
# hopper_uni_250
# anttrap_omni_250

# %%
run_counts = df.groupby(['env', 'algo',])['run'].nunique()
run_counts
# Out:
# env               algo
# ant_omni_250      dcg_me     120
#                   mcpg_me    120
#                   me         120
#                   memes      100
#                   pga_me     120
#                   ppga        15
# ant_uni_250       dcg_me     120
#                   mcpg_me    120
#                   me         120
#                   memes      100
#                   pga_me     120
#                   ppga        15
# anttrap_omni_250  dcg_me     120
#                   mcpg_me    120
#                   me         120
#                   memes      100
#                   pga_me     120
#                   ppga        15
# hopper_uni_250    dcg_me     120
#                   mcpg_me    120
#                   me         120
#                   memes      100
#                   pga_me     120
#                   ppga        15
# walker2d_uni_250  dcg_me     120
#                   mcpg_me    120
#                   me         120
#                   memes      100
#                   pga_me     119
#                   ppga        15
# Name: run, dtype: int64

# %%
idx = df.groupby(["env", "algo", "run"])["iteration"].idxmax()
df_last_iteration = df.loc[idx]
df = df_last_iteration[['env', 'algo', 'time', 'qd_score', 'batch_size']]

#df = df.groupby(['env', 'algo', 'batch_size'])[['qd_score', 'time']].median().reset_index()


df[['qd_score', 'time']] = df.groupby(['env', 'algo'])[['qd_score', 'time']].transform(
    lambda x: (x - x.min()) / (x.max() - x.min())
)

df = df.groupby(['env', 'algo', 'batch_size'])[['qd_score', 'time']].median().reset_index()

df['time'] = 1 - df['time']

df['scalability_score'] = df['qd_score'] * df['time']

#df['scalability_score'] = (0.5 * df['qd_score']) + (0.5 * df['time'])

df = df.groupby(['algo', 'batch_size'])[['scalability_score']].mean().reset_index()
# Out:
# /tmp/ipykernel_2048947/3618727835.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['qd_score', 'time']] = df.groupby(['env', 'algo'])[['qd_score', 'time']].transform(

# %%
df = df.groupby(['algo', 'batch_size'])[['scalability_score']].median().reset_index()

# %%
df
# Out:
#        algo  batch_size  scalability_score
# 0    dcg_me         256           0.016362
# 1    dcg_me         512           0.418474
# 2    dcg_me        1024           0.641600
# 3    dcg_me        2048           0.649464
# 4    dcg_me        4096           0.482214
# 5    dcg_me        8192           0.284610
# 6   mcpg_me         256           0.017324
# 7   mcpg_me         512           0.309343
# 8   mcpg_me        1024           0.469958
# 9   mcpg_me        2048           0.504896
# 10  mcpg_me        4096           0.548195
# 11  mcpg_me        8192           0.487798
# 12       me         256           0.019362
# 13       me         512           0.244094
# 14       me        1024           0.353293
# 15       me        2048           0.463333
# 16       me        4096           0.485993
# 17       me        8192           0.507047
# 18    memes         512           0.246833
# 19    memes        1024           0.104430
# 20    memes        2048           0.273659
# 21    memes        4096           0.440351
# 22    memes        8192           0.583566
# 23   pga_me         256           0.015256
# 24   pga_me         512           0.304456
# 25   pga_me        1024           0.433952
# 26   pga_me        2048           0.389777
# 27   pga_me        4096           0.345689
# 28   pga_me        8192           0.280716
# 29     ppga        3000           0.040666
# 30     ppga        4800           0.374872
# 31     ppga        6000           0.459279

# %%
df[df['algo'] == 'mcpg_me']
# Out:
#                   env     algo  batch_size  qd_score      time  \
# 6        ant_omni_250  mcpg_me         256  0.726272  0.058172
# 7        ant_omni_250  mcpg_me         512  0.595519  0.580629
# 8        ant_omni_250  mcpg_me        1024  0.550639  0.814957
# 9        ant_omni_250  mcpg_me        2048  0.604997  0.921575
# 10       ant_omni_250  mcpg_me        4096  0.604412  0.953719
# 11       ant_omni_250  mcpg_me        8192  0.703058  0.999313
# 35        ant_uni_250  mcpg_me         256  0.593243  0.054696
# 36        ant_uni_250  mcpg_me         512  0.460759  0.580980
# 37        ant_uni_250  mcpg_me        1024  0.545874  0.817216
# 38        ant_uni_250  mcpg_me        2048  0.645339  0.925281
# 39        ant_uni_250  mcpg_me        4096  0.610278  0.957701
# 40        ant_uni_250  mcpg_me        8192  0.545604  0.998767
# 67   anttrap_omni_250  mcpg_me         256  0.597893  0.002283
# 68   anttrap_omni_250  mcpg_me         512  0.590032  0.534982
# 69   anttrap_omni_250  mcpg_me        1024  0.630654  0.758213
# 70   anttrap_omni_250  mcpg_me        2048  0.501352  0.904477
# 71   anttrap_omni_250  mcpg_me        4096  0.655120  0.969556
# 72   anttrap_omni_250  mcpg_me        8192  0.554901  0.998348
# 96     hopper_uni_250  mcpg_me         256  0.376330  0.011815
# 97     hopper_uni_250  mcpg_me         512  0.366529  0.716825
# 98     hopper_uni_250  mcpg_me        1024  0.377079  0.947280
# 99     hopper_uni_250  mcpg_me        2048  0.439578  0.989559
# 100    hopper_uni_250  mcpg_me        4096  0.459414  0.934488
# 101    hopper_uni_250  mcpg_me        8192  0.302619  0.949002
# 128  walker2d_uni_250  mcpg_me         256  0.551717  0.004270
# 129  walker2d_uni_250  mcpg_me         512  0.453741  0.626431
# 130  walker2d_uni_250  mcpg_me        1024  0.670505  0.877781
# 131  walker2d_uni_250  mcpg_me        2048  0.712255  0.957642
# 132  walker2d_uni_250  mcpg_me        4096  0.472278  0.963483
# 133  walker2d_uni_250  mcpg_me        8192  0.430184  0.990627
#
#      scalability_score
# 6             0.042248
# 7             0.345776
# 8             0.448747
# 9             0.557550
# 10            0.576439
# 11            0.702575
# 35            0.032448
# 36            0.267692
# 37            0.446097
# 38            0.597120
# 39            0.584464
# 40            0.544931
# 67            0.001365
# 68            0.315656
# 69            0.478170
# 70            0.453461
# 71            0.635175
# 72            0.553984
# 96            0.004446
# 97            0.262737
# 98            0.357199
# 99            0.434988
# 100           0.429317
# 101           0.287186
# 128           0.002356
# 129           0.284237
# 130           0.588556
# 131           0.682085
# 132           0.455032
# 133           0.426152

# %%
df[df['algo']=='pga_me']
# Out:
#                   env    algo  batch_size  qd_score      time
# 19       ant_omni_250  pga_me         256  0.000000  0.000000
# 20       ant_omni_250  pga_me         512  0.383819  0.600231
# 21       ant_omni_250  pga_me        1024  0.254231  0.880684
# 22       ant_omni_250  pga_me        2048  0.341926  0.944427
# 23       ant_omni_250  pga_me        4096  1.000000  1.000000
# 43        ant_uni_250  pga_me         256  1.000000  0.000000
# 44        ant_uni_250  pga_me         512  0.922535  0.603176
# 45        ant_uni_250  pga_me        1024  0.982445  0.886774
# 46        ant_uni_250  pga_me        2048  0.712709  0.949095
# 47        ant_uni_250  pga_me        4096  0.000000  1.000000
# 67   anttrap_omni_250  pga_me         256  0.193678  0.000000
# 68   anttrap_omni_250  pga_me         512  0.200725  0.594018
# 69   anttrap_omni_250  pga_me        1024  1.000000  0.856764
# 70   anttrap_omni_250  pga_me        2048  0.000000  0.938527
# 71   anttrap_omni_250  pga_me        4096  0.327113  1.000000
# 91     hopper_uni_250  pga_me         256  1.000000  0.000000
# 92     hopper_uni_250  pga_me         512  0.911276  0.618290
# 93     hopper_uni_250  pga_me        1024  0.395768  0.895947
# 94     hopper_uni_250  pga_me        2048  0.290435  0.949142
# 95     hopper_uni_250  pga_me        4096  0.000000  1.000000
# 115  walker2d_uni_250  pga_me         256  0.723526  0.000000
# 116  walker2d_uni_250  pga_me         512  1.000000  0.611416
# 117  walker2d_uni_250  pga_me        1024  0.799433  0.896761
# 118  walker2d_uni_250  pga_me        2048  0.669340  0.954054
# 119  walker2d_uni_250  pga_me        4096  0.000000  1.000000

# %%
df = df.loc[df.groupby(['algo'])['scalability_score'].idxmax()]

# %%
df
# Out:
#        algo  batch_size  scalability_score
# 3    dcg_me        2048           0.649464
# 10  mcpg_me        4096           0.548195
# 17       me        8192           0.507047
# 22    memes        8192           0.583566
# 25   pga_me        1024           0.433952
# 31     ppga        6000           0.459279
